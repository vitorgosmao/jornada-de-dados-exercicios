# %% [markdown]
# # <b>Tipos Primitivos</b>

# %% [markdown]
# ## <b>Inteiros (int)</b>

# %% [markdown]
# ### 1. Escreva um programa que soma dois números inteiros inseridos pelo usuário.

# %%
def soma_inteiros(num1, num2):
    return num1 + num2

# %%
num1 = int(input("Digite o primeiro número inteiro: "))
print(num1)
# Out:
# 25

# %%
num2 = int(input("Digite o segundo número inteiro: "))
print(num2)
# Out:
# 75

# %%
print(f"Resultado da soma: {soma_inteiros(num1, num2)}")
# Out:
# Resultado da soma: 100

# %% [markdown]
# ### 2. Crie um programa que receba um número do usuário e calcule o resto da divisão desse número por 5.

# %%
def resto_divisao_por_5(num):
    return num % 5

# %%
num = int(input("Digite um número inteiro: "))
print(num)
# Out:
# 86

# %%
print(f"Resto da divisão por 5 é {resto_divisao_por_5(num)}")
# Out:
# Resto da divisão por 5 é 1

# %% [markdown]
# ### 3. Desenvolva um programa que multiplique dois números fornecidos pelo usuário e mostre o resultado.

# %%
def multiplicacao(num1, num2):
    return num1 * num2

# %%
num1 = int(input("Digite o primeiro número da multiplicação: "))
print(num1)
# Out:
# 5

# %%
num2 = int(input("Digite o segundo número da multiplicação: "))
print(num2)
# Out:
# 10

# %%
print(f"Resultado da multiplicação de {num1} por {num2} é {multiplicacao(num1, num2)}")
# Out:
# Resultado da multiplicação de 5 por 10 é 50

# %% [markdown]
# ### 4. Faça um programa que peça dois números inteiros e imprima a divisão inteira do primeiro pelo segundo.

# %%
def divisao(dividendo, divisor):
    return dividendo//divisor

# %%
dividendo = int(input("Digite o dividendo: "))
print(dividendo)
# Out:
# 100

# %%
divisor = int(input("Digite o divisor: "))
print(divisor)
# Out:
# 3

# %%
print(f"Resultado da divisao de {dividendo} por {divisor} é {divisao(dividendo, divisor)}")
# Out:
# Resultado da divisao de 100 por 3 é 33

# %% [markdown]
# ### 5. Escreva um programa que calcule o quadrado de um número fornecido pelo usuário.

# %%
def quadrado(num):
    return num ** 2

# %%
num = int(input("Digite um número: "))
print(num)
# Out:
# 6

# %%
print(f"O quadrado de {num} é {quadrado(num)}")
# Out:
# O quadrado de 6 é 36

# %% [markdown]
# ## <b>Números de Ponto Flutuante (float) </b>

# %% [markdown]
# ### 6. Escreva um programa que receba dois números flutuantes e realize sua adição.

# %%
def soma_float(num1, num2):
    return num1 + num2

# %%
num1 = float(input("Digite o primeiro número flutuante: "))
print(num1)
# Out:
# 5.5

# %%
num2 = float(input("Digite o segundo número flutuante: "))
print(num2)
# Out:
# 4.5

# %%
print(f"Restultado da soma entre {num1} e {num2} é {soma_float(num1, num2)}")
# Out:
# Restultado da soma entre 5.5 e 4.5 é 10.0

# %% [markdown]
# ### 7. Crie um programa que calcule a média de dois números flutuantes fornecidos pelo usuário.

# %%
def media_2_float(num1, num2):
    return (num1 + num2)/2

# %%
num1 = float(input("Digite o primeiro número flutuante: "))
print(num1)
# Out:
# 9.5

# %%
num2 = float(input("Digite o segundo número flutuante: "))
print(num2)
# Out:
# 1.5

# %%
print(f"Valor médio entre {num1} e {num2} é {media_2_float(num1, num2)} ")
# Out:
# Valor médio entre 9.5 e 1.5 é 5.5

# %% [markdown]
# ### 8. Desenvolva um programa que calcule a potência de um número (base e expoente fornecidos pelo usuário).

# %%
def potencia(base, expoente):
    return base ** expoente

# %%
base = float(input("Digite a base: "))
print(base)
# Out:
# 5.0

# %%
expoente = float(input("Digite o expoente: "))
print(expoente)
# Out:
# 2.0

# %%
print(f"O resultado da potência é {potencia(base, expoente)}")
# Out:
# O resultado da potência é 25.0

# %% [markdown]
# ### 9. Faça um programa que converta a temperatura de Celsius para Fahrenheit.

# %%
def celsius_fahrenheit(temp_celsius):
    return (temp_celsius * (9/5)) + 32

# %%
temp_celsius = float(input("Digite a temperatura em Celsius: "))
print(temp_celsius)
# Out:
# 31.0

# %%
print(f"{temp_celsius}°C é igual a {celsius_fahrenheit(temp_celsius):.2f}°F")
# Out:
# 31.0°C é igual a 87.80°F

# %% [markdown]
# ### 10. Escreva um programa que calcule a área de um círculo, recebendo o raio como entrada.

# %%
PI = 3.14159

# %%
def area_circulo(raio):
    return PI * raio ** 2

# %%
raio = float(input("Digite o raio do círculo: "))
print(raio)
# Out:
# 3.0

# %%
print(f"A área do círculo de raio {raio} é igual a {area_circulo(raio):.2f}")
# Out:
# A área do círculo de raio 3.0 é igual a 28.27

# %% [markdown]
# ## <b> Strings (str) </b>

# %% [markdown]
# ### 11. Escreva um programa que receba uma string do usuário e a converta para maiúsculas.

# %%
def string_maiuscula(string):
    return string.upper()

# %%
string = input("Digite uma palavra ou frase: ")
print(f"String inserida: {string} \nString em maiusculo: {string_maiuscula(string)}")
# Out:
# String inserida: Ola
# String em maiusculo: OLA

# %% [markdown]
# ### 12. Crie um programa que receba o nome completo do usuário e imprima o nome com todas as letras minúsculas.

# %%
def string_minuscula(string):
    return string.lower()

# %%
string = input("Digite seu nome: ")
print(f"Nome inserido: {string} \nNome em minusculo: {string_minuscula(string)}")
# Out:
# Nome inserido: Vitor
# Nome em minusculo: vitor

# %% [markdown]
# ### 13. Desenvolva um programa que peça ao usuário para inserir uma frase e, em seguida, imprima esta frase sem espaços em branco no início e no final.

# %%
frase = " frase com espaços          "

# %%
frase_sem_espaco = frase.strip()
print(frase_sem_espaco)
# Out:
# frase com espaços

# %% [markdown]
# ### 14. Faça um programa que peça ao usuário para digitar uma data no formato "dd/mm/aaaa" e, em seguida, imprima o dia, o mês e o ano separadamente.

# %%
data = '11/11/2000'

# %%
dia, mes, ano = data.split("/")
print(f"Dia: {dia}\nMês: {mes}\nAno :{ano}")
# Out:
# Dia: 11
# Mês: 11
# Ano :2000

# %% [markdown]
# ### 15. Escreva um programa que concatene duas strings fornecidas pelo usuário.

# %%
str1 = "ola"
str2 = "mundo"

# %%
resultado = str1 + str2
print(resultado)
# Out:
# olamundo

# %% [markdown]
# ## <b>Booleanos(bool)</b>

# %% [markdown]
# ### 16. Escreva um programa que avalie duas expressões booleanas inseridas pelo usuário e retorne o resultado da operação AND entre elas.

# %%
valor1 = True
valor2 = False

# %%
resultado = valor1 and valor2
print(resultado)
# Out:
# False

# %% [markdown]
# ### 17. Crie um programa que receba dois valores booleanos do usuário e retorne o resultado da operação OR.

# %%
valor1 = True
valor2 = True 
resultado = valor1 or valor2
print(resultado)
# Out:
# True

# %% [markdown]
# ### 18. Desenvolva um programa que peça ao usuário para inserir um valor booleano e, em seguida, inverta esse valor.

# %%
valor = True

resultado = not valor

print(resultado)
# Out:
# False

# %% [markdown]
# ### 19. Faça um programa que compare se dois números fornecidos pelo usuário são iguais.

# %%
n1 = 30 
n2 = 60 

if (n1 == n2): 
    print("Valores iguais")
else:
    print("Valores diferentes")
# Out:
# Valores diferentes

# %% [markdown]
# ### 20. Escreva um programa que verifique se dois números fornecidos pelo usuário são diferentes.

# %%
n1 = 30 
n2 = 60 

if (n1 != n2): 
    print("Valores diferentes")
else:
    print("Valores iguais")
# Out:
# Valores diferentes
