# %% [markdown]
# # Estruturas de Controle de Fluxo

# %% [markdown]
# ## <b>IF</B>

# %% [markdown]
# ### 1. Verificação de Qualidade de Dados
# Você está analisando um conjunto de dados de vendas e precisa garantir que todos os registros tenham valores positivos para quantidade e preço. Escreva um programa que verifique esses campos e imprima "Dados válidos" se ambos forem positivos ou "Dados inválidos" caso contrário.

# %%
def verifica_validade(qtd, preco):
    if qtd > 0 and preco > 0: 
        print("Dados válidos!")
    else:
        print("Dados inválidos.")

# %% [markdown]
# ### Exercício 2: Classificação de Dados de Sensor
# Imagine que você está trabalhando com dados de sensores IoT. Os dados incluem medições de temperatura. Você precisa classificar cada leitura como 'Baixa', 'Normal' ou 'Alta'. Considerando que:
#
# 1. Temperatura < 18°C é 'Baixa'
# 2. Temperatura >= 18°C e <= 26°C é 'Normal'
# 3. Temperatura > 26°C é 'Alta'

# %%
def classifica_temperatura(temperatura):
    if temperatura < 18: 
        return "Baixa"
    elif (temperatura >= 18) and (temperatura <= 26):
        return ("Normal")
    else:
        return ("Alta")

# %%
temperatura1 = 10
temperatura2 = 20
temperatura3 = 30

# %%
print(f" Temperaturas informadas e suas classificações\
      \n{temperatura1}°C -> {classifica_temperatura(temperatura1)}\
      \n{temperatura2}°C -> {classifica_temperatura(temperatura2)}\
      \n{temperatura3}°C -> {classifica_temperatura(temperatura3)}")
# Out:
#  Temperaturas informadas e suas classificações
# 10°C -> Baixa
# 20°C -> Normal
# 30°C -> Alta

# %% [markdown]
# ### Exercício 3: Filtragem de Logs por Severidade
# Você está analisando logs de uma aplicação e precisa filtrar mensagens com severidade 'ERROR'. Dado um registro de log em formato de dicionário como log = {'timestamp': '2021-06-23 10:00:00', 'level': 'ERROR', 'message': 'Falha na conexão'}, escreva um programa que imprima a mensagem se a severidade for 'ERROR'.

# %%
log = {'timestamp': '2021-06-23 10:00:00', 'level': 'ERROR', 'message': 'Falha na conexão'}

# %%
if log['level'] == 'ERROR':
    print(log['message'])
# Out:
# Falha na conexão

# %% [markdown]
# ### Exercício 4: Validação de Dados de Entrada
# Antes de processar os dados de usuários em um sistema de recomendação, você precisa garantir que cada usuário tenha idade entre 18 e 65 anos e tenha fornecido um email válido. Escreva um programa que valide essas condições e imprima "Dados de usuário válidos" ou o erro específico encontrado.

# %%
def verifica_idade(idade):
    if 18 <= idade <= 65:
        return True
    else:
        return False

# %%
def verifica_email(email):
    if "@" not in email or "." not in email: 
        return False
    else:
        return True

# %%
def verifica_entrada (idade, email):
    resultado_email = verifica_email(email)
    resultado_idade = verifica_idade(idade)

    if resultado_email and resultado_idade: 
        print("Dados inseridos com sucesso!")
    elif resultado_idade != True:
        print("Idade inválida")
    else:
        print("E-mail inválido")

# %%
idade = int(input("Digite sua idade: "))
email = input("Digite seu email: ")

print(idade, email)

verifica_entrada(idade, email)
# Out:
# 18 vitor@email.com
# Dados inseridos com sucesso!

# %% [markdown]
# ### Exercício 5: Detecção de Anomalias em Dados de Transações
# Você está trabalhando em um sistema de detecção de fraude e precisa identificar transações suspeitas. Uma transação é considerada suspeita se o valor for superior a R$ 10.000 ou se ocorrer fora do horário comercial (antes das 9h ou depois das 18h). Dada uma transação como transacao = {'valor': 12000, 'hora': 20}, verifique se ela é suspeita.

# %%
transacao = {'valor': 9000, 'hora': 25}

# %%
def detecta_anomalia(transacao):
    if transacao['valor'] > 10000 or 9 > transacao['hora'] > 18:
        print("Anomalia detectada")
    else:
        print("Transação dentro da normalidade")

# %%
detecta_anomalia(transacao)
# Out:
# Transação dentro da normalidade

# %% [markdown]
# ## <b>FOR</b>

# %% [markdown]
# ### 6. Contagem de Palavras em Textos
# Objetivo: Dado um texto, contar quantas vezes cada palavra única aparece nele.

# %%
frase = 'frase com palavras palavras a a a a'

# %%
def contador_de_palavras_unicas(frase):
    contagem_palavras = {}
    palavras = frase.split() # split separa um string baseada em um delimitador

    for palavra in palavras:
        if palavra in contagem_palavras:
            contagem_palavras[palavra] += 1
        else:
            contagem_palavras[palavra] = 1
    
    print(contagem_palavras)

# %%
contador_de_palavras_unicas('frase com palavras palavras a a a a')
# Out:
# {'frase': 1, 'com': 1, 'palavras': 2, 'a': 4}

# %% [markdown]
# ### 7. Normalização de Dados
# Objetivo: Normalizar uma lista de números para que fiquem na escala de 0 a 1.

# %%
numeros = [23 ,54, 2, 65, 2564, 23, 34]

# %%
def normalizar_numeros(lista_numeros):
    minimo = min(numeros)
    maximo = max(numeros)

    normalizados = [(x - minimo)/(maximo - minimo) for x in numeros] 

    print(normalizados)

# %%
normalizar_numeros(numeros)
# Out:
# [0.00819672131147541, 0.02029664324746292, 0.0, 0.02459016393442623, 1.0, 0.00819672131147541, 0.01249024199843872]

# %% [markdown]
# ### 8. Filtragem de Dados Faltantes
# Objetivo: Dada uma lista de dicionários representando dados de usuários, filtrar aqueles que têm um campo específico faltando.

# %%
usuarios = [
    {"nome": "Alice", "email": "alice@example.com"},
    {"nome": "Bob", "email": ""},
    {"nome": "Carol", "email": "carol@example.com"}
]

# %%
usuarios_validos = [
    usuario for usuario in usuarios if usuario["email"] # inclui no dicionario "usuarios_validos" somente aqueles em que usuarios["email"] for true 
]

# %%
print(usuarios_validos)
# Out:
# [{'nome': 'Alice', 'email': 'alice@example.com'}, {'nome': 'Carol', 'email': 'carol@example.com'}]

# %% [markdown]
# ### 9. Extração de Subconjuntos de Dados
# Objetivo: Dada uma lista de números, extrair apenas aqueles que são pares.

# %%
numeros = range(1, 11)

# %%
pares = [ numero for numero in numeros if numero % 2 == 0]
print (pares)
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# ### 10. Agregação de Dados por Categoria
# Objetivo: Dado um conjunto de registros de vendas, calcular o total de vendas por categoria.

# %%
vendas = [
    {"categoria": "eletro", "valor": 500},
    {"categoria": "livros", "valor": 20},
    {"categoria": "eletro", "valor": 100},
    {"categoria": "roupas", "valor": 150},
    {"categoria": "eletro", "valor": 250}
]

# %%
total_por_categoria = {}

for venda in vendas:
    categoria = venda["categoria"]
    valor = venda["valor"]
    if categoria in total_por_categoria:
        total_por_categoria[categoria] += valor 
    else:
        total_por_categoria[categoria] = valor

# %%
print(total_por_categoria)
# Out:
# {'eletro': 850, 'livros': 20, 'roupas': 150}

# %% [markdown]
# ## <b> WHILE </b>

# %% [markdown]
# ### 11. Leitura de Dados até Flag
# Objetivo: Ler dados de entrada até que uma palavra-chave específica ("sair") seja fornecida.

# %%
dados = []

entrada = ""

while entrada.lower() != "sair":
    entrada = input("Digite um valor, ou sair para terminar:")
    
    if entrada.lower() != "sair":
        dados.append(entrada)

print(dados)
# Out:
# ['alou', 'ou', 'oi', 'teste', 'alalalalalaa']

# %% [markdown]
# ### 12. Validação de Entrada
# Objetivo: Solicitar ao usuário um número dentro de um intervalo específico até que a entrada seja válida.

# %%
numero = int(input("Digite um numero entre 0 e 5"))
while  numero < 0 or numero > 5:
      print("Número ")
      numero = int(input("Digite um numero entre 0 e 5"))
      numero

# %% [markdown]
# ### 13. Consumo de API Simulado
# Objetivo: Simular o consumo de uma API paginada, onde cada "página" de dados é processada em loop até que não haja mais páginas.

# %% [markdown]
# ### 14. Tentativas de Conexão
# Objetivo: Simular tentativas de reconexão a um serviço com um limite máximo de tentativas.

# %% [markdown]
# ### 15. Processamento de Dados com Condição de Parada
# Objetivo: Processar itens de uma lista até encontrar um valor específico que indica a parada.

# %% [markdown]
# ### Desafio:
# Integre na solução anterior um fluxo de While que repita o fluxo até que o usuário insira as informações corretas
